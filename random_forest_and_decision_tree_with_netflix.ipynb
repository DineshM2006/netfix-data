# %%
import os
os.environ['KAGGLE_USERNAME']='dinesh223344'
os.environ['KAGGLE_KEY']='KGAT_4f293546a7b4700c41008b912382b767'

# %%
# !kaggle datasets download -d 'imtkaggleteam/netflix'
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/imtkaggleteam/netflix
# License(s): other
# ...
# 100% 1.17M/1.17M [00:00<00:00, 118MB/s]

# %%
import pandas as pd
df=pd.read_csv('/content/netflix.zip')

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
df.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %%
df.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %%
df.drop('duration',axis=1,inplace=True)

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  \
# 0  14-Aug-20          2020  TV-MA
# ...

# %%
df.drop('description',axis=1,inplace=True)

# %%
df.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  \
# 0  14-Aug-20          2020  TV-MA
# ...

# %%
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# genres             0
# dtype: int64

# %%
df['rating']=df['rating'].fillna(df['rating'].mode()[0])

# %%
df['country']=df['country'].fillna(df['country'].mode()[0])

# %%
df['director']=df['director'].fillna(df['director'].mode()[0])

# %%
df['cast']=df['cast'].fillna(df['cast'].mode()[0])

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# genres           0
# dtype: int64

# %%
df.head()
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
#
#                  director                                               cast  \
# 0  Raúl Campos, Jan Suter  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4  Raúl Campos, Jan Suter                                 David Attenborough
#
#           country date_added  release_year rating  \
# 0          Brazil  14-Aug-20          2020  TV-MA
# ...

# %%
df['date_added']=df['date_added'].fillna(df['date_added'].mode()[0])

# %%
df['overall_year']=2026-df['release_year']

# %%
df.head()
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
#
#                  director                                               cast  \
# 0  Raúl Campos, Jan Suter  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4  Raúl Campos, Jan Suter                                 David Attenborough
#
#           country date_added  release_year rating  \
# 0          Brazil  14-Aug-20          2020  TV-MA
# ...

# %%
df['rating'].unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', 'UR', 'NC-17'], dtype=object)

# %%
df['numeric_rating']=df['rating'].replace({'TV-MA':1,'TV-PG':2,'R':3,'TV-G':4,'PG-13':5,'TV-14':6,'TV-Y':7,'PG':8,'TV-Y7':9,'NR':10,'G':11,'TV-Y7-FV':12,'UR':13,'NC-17':14})
# Out:
# /tmp/ipykernel_6354/2626285237.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['numeric_rating']=df['rating'].replace({'TV-MA':1,'TV-PG':2,'R':3,'TV-G':4,'PG-13':5,'TV-14':6,'TV-Y':7,'PG':8,'TV-Y7':9,'NR':10,'G':11,'TV-Y7-FV':12,'UR':13,'NC-17':14})

# %%
df.head()
# Out:
#   show_id     type                                      title  \
# 0      s1  TV Show                                         3%
# 1     s10    Movie                                       1920
# 2    s100    Movie                                 3 Heroines
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4   s1001  TV Show                             Blue Planet II
#
#                  director                                               cast  \
# 0  Raúl Campos, Jan Suter  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1            Vikram Bhatt  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...
# 2          Iman Brotoseno  Reza Rahadian, Bunga Citra Lestari, Tara Basro...
# 3            Lev L. Spiro  Alan Ritchson, Darin Brooks, James Cade, Rob R...
# 4  Raúl Campos, Jan Suter                                 David Attenborough
#
#           country date_added  release_year rating  \
# 0          Brazil  14-Aug-20          2020  TV-MA
# ...

# %%
Q1 = df['numeric_rating'].quantile(0.25)
Q3 = df['numeric_rating'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['numeric_rating'] < lower_bound) | (df['numeric_rating'] > upper_bound)]
clean_df = df[(df['numeric_rating'] >= lower_bound) & (df['numeric_rating'] <= upper_bound)]

print("Outliers:")
print(outliers)

print(clean_df)
# Out:
# Outliers:
#      show_id   type                      title                director  \
# 2800   s3519  Movie                  Lady-Like  Raúl Campos, Jan Suter
# 5486   s5937  Movie        Swearnet: The Movie        Warren P. Sonoda
# 7784    s997  Movie  Blue Is the Warmest Color     Abdellatif Kechiche
#
#                                                    cast  \
# 2800  Allie Gallerani, Beverly D'Angelo, Olivia Lucc...
# 5486  Mike Smith, John Paul Tremblay, Robb Wells, Pa...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
#
#                      country date_added  release_year rating  \
# 2800           United States  18-Jan-19          2018  NC-17
# 5486                  Canada  24-Sep-17          2014  NC-17
# 7784  France, Belgium, Spain  26-Aug-16          2013  NC-17
#
#                                                 genres  overall_year  \
# 2800                      Comedies, Independent Movies             8
# ...

# %%
x=df.drop(['rating'],axis=1)
y=df['rating']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x = pd.get_dummies(x,drop_first=True)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=82)
X_train=scaler.fit_transform(x_train)
X_test=scaler.transform(x_test)
x.head()
# Out:
#    release_year  overall_year  numeric_rating  show_id_s10  show_id_s100  \
# 0          2020             6               1        False         False
# 1          2008            18               1         True         False
# 2          2016            10               2        False          True
# 3          2016            10               3        False         False
# 4          2017             9               4        False         False
#
#    show_id_s1000  show_id_s1001  show_id_s1002  show_id_s1003  show_id_s1004  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3           True          False          False          False          False
# 4          False           True          False          False          False
#
#    ...  genres_TV Dramas, TV Sci-Fi & Fantasy, Teen TV Shows  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.ensemble import RandomForestClassifier
model1=RandomForestClassifier()
model1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
model1.score(X_test,y_test)
# Out:
# 0.8552166934189406

# %%
import pickle
with open('model1.pkl','wb') as f:
  pickle.dump(model1,f)
from google.colab import files
files.download('model1.pkl')
